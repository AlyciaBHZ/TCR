# %%
import pandas as pd

df = pd.read_csv('val.csv')

# find those peptide is GLCTLVAML and print the corresponding cdr3_b
a = df[df['peptide'] == 'GLCTLVAML']['cdr3_b']
a.to_csv('GLCTLVAML.csv', index=False)
