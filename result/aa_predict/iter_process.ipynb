# %%
import pandas as pd

df = pd.read_csv('iter_1.0_GILGFVFTL_[2, 3, 4].csv')

# select the unique values from the 'final_sequence' column
unique_values = df['final_sequence'].unique()

print(unique_values)
# Out:
# ['ASSIFSSYDQY' 'ASNISSSYDQY' 'ASGSQSSYDQY' 'ASTSRSSYDQY' 'ASGSRSSYDQY'
#  'ASRGSSSYDQY']

# %%
# read from trn.csv
df2 = pd.read_csv('../../data/trn.csv')

#filter unique values that are not in trn.csv
filtered = [x for x in unique_values if x not in df2['cdr3_b'].values]

print(filtered)
# Out:
# ['ASSIFSSYDQY', 'ASNISSSYDQY', 'ASGSQSSYDQY', 'ASTSRSSYDQY', 'ASGSRSSYDQY', 'ASRGSSSYDQY']
